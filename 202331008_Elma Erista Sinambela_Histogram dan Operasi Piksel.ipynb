# %% [markdown]
# # Import Library

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np #Elma Erista Sinambela_202331008

# %% [markdown]
# # Membaca Data Gambar

# %%
img = cv2.imread('buah.png') #Elma Erista Sinambela_202331008

# %%
img.shape #Elma Erista Sinambela_202331008
# Out:
# (1200, 1200, 3)

# %%
[baris, kolom] = img.shape[:2] #Elma Erista Sinambela_202331008

# %% [markdown]
# # Convert BGR to RGB

# %%
plt.imshow(img) #Elma Erista Sinambela_202331008

# %%
RGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) #Elma Erista Sinambela_202331008

# %%
cv2.imshow('Image',img)
cv2.waitKey(1)
cv2.destroyAllWindows() #Elma Erista Sinambela_202331008

# %% [markdown]
# # Menampilkan Histogram

# %%
fig, axs = plt.subplots(2,2, figsize=(15,5))

#cara 1 dengan Matplotlib
axs[0,0].imshow(rgb)
axs[0,1].hist(rgb.ravel(),256,[0,256])

#cara 2 dengan OpenCV
hist = cv2.calcHist([rgb],[0], None,[256],[0,256])
axs[1,0].imshow(rgb)
axs[1,1].plot(hist)

#menampilkan
plt.show() #Elam Erista Sinambela_202331008

# %% [markdown]
# # Operasi Piksel Meningkatkan Kecerahan

# %%
beta = 40
citra_cerah = np.zeros ((baris, kolom, 3))

for x in range (baris):
    for y in range (kolom):
        gyx = rgb[x,y] + beta
        citra_cerah[x,y] = gyx

citra_cerah = citra_cerah.astype(np.uint8)

fig, axs = plt.subplots(2,2, figsize=(15,5))
axs[0,0].imshow(rgb)
axs[0,1].hist(rgb.ravel(),256,[0,256])
axs[1,0].imshow(citra_cerah)
axs[1,1].hist(citra_cerah.ravel(),256, [0,256])

plt.show() #ELma Erista Sinambela_202331008

# %% [markdown]
# # Operasi Piksel Meregangkan Kontras

# %%
alpha = 4
citra_kontras = np.zeros((baris, kolom, 3))

for x in range(baris):
    for y in range(kolom):
        gyx = rgb[x,y] * alpha
        citra_kontras[x,y] = gyx

citra_kontras = citra_kontras.astype(np.uint8)

fig, axs = plt.subplots(2,2, figsize=(15,5))
axs[0,0].imshow(rgb)
axs[0,1].hist(rgb.ravel(),256,[0,256])
axs[1,0].imshow(citra_kontras)
axs[1,1].hist(citra_kontras.ravel(),256,[0,256])

plt.show() #Elma Erista Sinambela_202331008

# %% [markdown]
# # Operasi Piksel Gabungan Antara Meningkatkan Kecerahan dan Meregangkan Kontras

# %%
beta = 10
alpha = 1.2
citra_hasil = np.zeros((baris, kolom, 3))

for x in range (baris):
    for y in range (kolom):
        gyx = alpha * rgb[x,y] + beta
        citra_hasil[x,y] = gyx

citra_hasil = citra_hasil.astype(np.uint8)

fig, axs = plt.subplots(2,2, figsize=(15,5))
axs[0,0].imshow(rgb)
axs[0,1].hist(rgb.ravel(),256,[0,256])
axs[1,0].imshow(citra_hasil)
axs[1,1].hist(citra_hasil.ravel(),256,[0,256])

plt.show() #Elma Erista Sinambela_202331008

# %% [markdown]
# # Membalik Citra

# %%
beta = 10 
alpha = 1.2
citra_negatif = np.zeros((baris, kolom, 3))

for x in range (baris):
    for y in range (kolom):
        fyx = 255 - rgb[x,y]
        citra_negatif[x,y] = fyx

citra_negatif = citra_negatif.astype(np.uint8)

fig, axs = plt.subplots(2,2, figsize=(15,5))
axs[0,0].imshow(rgb)
axs[0,1].hist(rgb.ravel(),256,[0,256])
axs[1,0].imshow(citra_negatif)
axs[1,1].hist(citra_negatif.ravel(),256,[0,256])

plt.show() #Elma Erista Sinambela_202331008

# %%
fig, axs = plt.subplots(5,2, figsize=(15,20))

#Gambar Asli
axs[0,0].imshow(rgb)
axs[0,1].hist(rgb.ravel(),256,[0,256])

#Peningkatan Kecerahan
axs[1,0].imshow(citra_cerah)
axs[1,1].hist(citra_cerah.ravel(),256, [0,256])

#Peregangan Kontras
axs[2,0].imshow(citra_kontras)
axs[2,1].hist(citra_kontras.ravel(),256,[0,256])

#Peningkatan Kecerahan dan Peregangan Kontras
axs[3,0].imshow(citra_hasil)
axs[3,1].hist(citra_hasil.ravel(),256,[0,256])

#Pembalikkan Citra
axs[4,0].imshow(citra_negatif)
axs[4,1].hist(citra_negatif.ravel(),256,[0,256])

plt.show() #Elma Erista Sinambela_202331008
